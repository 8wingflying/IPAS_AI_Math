# %% [markdown]
# # 📘 常見機率分布期望值與變異數
#
# 有時間可以推導底下的式子
# (1)使用定義計算期望值與變異數
#
# ---
#
# # 🟦 一、離散分布（Discrete Distributions）
#
# ---
#
# ## 1. Bernoulli 分布  $ \text{Bern}(p) $
# **PMF：**
# $$
# P(X=1)=p,\quad P(X=0)=1-p
# $$
#
#
#
# **Mean(平均值)**
# $$
# E[X]= P(X=1)*1+P(X=0)*0= p
# $$
#
# **Variance(變異數)**
# $$
# E[X^2]= P(X=1)*1^2+P(X=0)*0^2= p
# $$
#
# $$
# \mathrm{Var}(X)=E[X^2]-(E[X])^2=p-p^2=p(1-p)
# $$
#
#
# ---
#
# ## 2. 二項分布  $ \text{Bin}(n,p) $
# **PMF：**
# $$
# P(X=x)=\binom{n}{x} p^x (1-p)^{n-x}
# $$
#
#
#
# **Mean(平均值)**
# $$
# E[X]=np
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=np(1-p)
# $$
#
#
# ---
#
# ## 3. Poisson 分布  $ \text{Pois}(\lambda) $
# **PMF：**
# $$
# P(X=k)=\frac{e^{-\lambda}\lambda^k}{k!}
# $$
#
#
#
# **Mean(平均值)**
# $$
# E[X]=\lambda
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=\lambda
# $$
#
#
# ---
#
# ## 4. 幾何分布（Geometric） $ \text{Geom}(p) $
# （定義為「第一次成功所需的試驗次數」）
#
# **PMF：**
# $$
# P(X=k)=p(1-p)^{k-1},\quad k=1,2,\dots
# $$
#
#
#
#
# **Mean(平均值)**
# $$
# E[X]=\frac{1}{p}
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=\frac{1-p}{p^2}
# $$
#
#
# ---
#
# ## 5. 負二項分布（Negative Binomial） $ \text{NB}(r,p) $
#
# **PMF：**
# $$
# P(X=k)=\binom{k+r-1}{k}(1-p)^k p^r
# $$
#
#
#
# **Mean(平均值)**
# $$
# E[X]=r\frac{1-p}{p}
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=r\frac{1-p}{p^2}
# $$
#
#
#
# ---
#
# ## 6. 超幾何分布（Hypergeometric） $ \text{Hypergeo}(N,K,n) $
#
# **PMF：**
# $$
# P(X=k)=\frac{\binom{K}{k}\binom{N-K}{n-k}}{\binom{N}{n}}
# $$
#
#
# **Mean(平均值)**
# $$
# E[X]=n\frac{K}{N}
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=n\frac{K}{N}\left(1-\frac{K}{N}\right)\frac{N-n}{N-1}
# $$
#
#
# ---
#
# # 🟩 二、連續分布（Continuous Distributions）
#
# 對連續型隨機變數 \\(X\\)，其 PDF 為 \\(f(x)\\)，期望值定義為：
#
# $$
# E[X] = \int_{-\infty}^{\infty} x f(x) dx
# $$
#
# 條件：
#
# $f(x) \ge 0 $
#
# $\int f(x) dx = 1 $
#
# 積分需收斂
#
# ---
#
# ## 7. 均勻分布（Uniform） $ U(a,b) $
#
# **PDF：**
# $$
# f_X(x)=\frac{1}{b-a},\quad a\le x\le b
# $$
#
#
#
#
# **Mean(平均值)**
# $$
# E[X] = \int_{a}^{b} x f(x) dx = \int_{a}^{b} x \frac{1}{b-a} dx
# =\frac{a+b}{2}
# $$
#
# **Variance(變異數)**
#
# $$
# E[X^2]= = \int_{a}^{b} x^2 f(x) = \cdots
# $$
#
# $$
# \mathrm{Var}(X)=E[X^2]-(E[X])^2= \cdots =\frac{(b-a)^2}{12}
# $$
#
#
#
#
# ---
#
# ## 8. 指數分布（Exponential） $ \text{Exp}(\lambda) $
#
# **PDF：**
# $$
# f_X(x)=\lambda e^{-\lambda x},\quad x\ge 0
# $$
#
#
#
# **Mean(平均值)**
# $$
# E[X]=\frac{1}{\lambda}
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=\frac{1}{\lambda^2}
# $$
#
#
# ---
#
# ## 9. Gamma 分布（Gamma） $ \Gamma(k,\lambda) $
#
# **PDF：**
# $$
# f_X(x)=\frac{\lambda^k}{\Gamma(k)}x^{k-1}e^{-\lambda x}
# $$
#
#
# **Mean(平均值)**
# $$
# E[X]=\frac{k}{\lambda}
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=\frac{k}{\lambda^2}
# $$
#
#
# ---
#
# ## 10. 常態分布（Normal） $ N(\mu,\sigma^2) $
#
# **PDF：**
# $$
# f_X(x)=\frac{1}{\sqrt{2\pi}\sigma}\exp\left(-\frac{(x-\mu)^2}{2\sigma^2}\right)
# $$
#
#
# **Mean(平均值)**
# $$
# E[X]=\mu
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=\sigma^2
# $$
#
#
# ---
#
# ## 11. Beta 分布（Beta） $ \text{Beta}(\alpha,\beta) $
#
# **PDF：**
# $$
# f_X(x)=\frac{1}{B(\alpha,\beta)}x^{\alpha-1}(1-x)^{\beta-1}
# $$
#
#
# **Mean(平均值)**
# $$
# E[X]=\frac{\alpha}{\alpha+\beta}
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=\frac{\alpha\beta}{(\alpha+\beta)^2(\alpha+\beta+1)}
# $$
#
# ---
#
# ## 12. 卡方分布（Chi-square） $ \chi^2(k) $
#
# **PDF：**
# $$
# f_X(x)=\frac{1}{2^{k/2}\Gamma(k/2)}x^{k/2-1}e^{-x/2}
# $$
#
#
#
# **Mean(平均值)**
# $$
# E[X]=k
# $$
#
# **Variance(變異數)**
# $$
# \mathrm{Var}(X)=2k
# $$
